# %%
import os.path

from adios2 import FileReader

ATTR = 'Greeting'

ips_analysis_data = ips_analysis_api.get_data()
for timestep, filelist in ips_analysis_data.items():
    print(timestep)
    print('-----------')
    for file in filelist:
        print(os.path.basename(file))
        with FileReader(file) as fh:
            print(fh.read(ATTR))
    print()
